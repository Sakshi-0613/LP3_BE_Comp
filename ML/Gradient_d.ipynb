# %%
import matplotlib.pyplot as plt

# %%
def func(x):
    return (x+3)**2

def grad(x):
    return 2*(x+3)

# %%
#parameters for gradient descent
x=2
learning_rate=0.1
epochs=50

x_vals = [x]
y_vals=[func(x)]

# %%
for i in range(epochs):
    dx=grad(x)
    x= x-learning_rate*dx
    x_vals.append(x)
    y_vals.append(func(x))
    print(f"Iterartion {i+1}: x= {x:.5f}, f(x)= {func(x):.5f}")
# Out:
# Iterartion 1: x= -2.99994, f(x)= 0.00000
# Iterartion 2: x= -2.99995, f(x)= 0.00000
# Iterartion 3: x= -2.99996, f(x)= 0.00000
# Iterartion 4: x= -2.99997, f(x)= 0.00000
# Iterartion 5: x= -2.99998, f(x)= 0.00000
# Iterartion 6: x= -2.99998, f(x)= 0.00000
# Iterartion 7: x= -2.99999, f(x)= 0.00000
# Iterartion 8: x= -2.99999, f(x)= 0.00000
# Iterartion 9: x= -2.99999, f(x)= 0.00000
# Iterartion 10: x= -2.99999, f(x)= 0.00000
# Iterartion 11: x= -2.99999, f(x)= 0.00000
# Iterartion 12: x= -3.00000, f(x)= 0.00000
# Iterartion 13: x= -3.00000, f(x)= 0.00000
# Iterartion 14: x= -3.00000, f(x)= 0.00000
# Iterartion 15: x= -3.00000, f(x)= 0.00000
# Iterartion 16: x= -3.00000, f(x)= 0.00000
# Iterartion 17: x= -3.00000, f(x)= 0.00000
# Iterartion 18: x= -3.00000, f(x)= 0.00000
# Iterartion 19: x= -3.00000, f(x)= 0.00000
# Iterartion 20: x= -3.00000, f(x)= 0.00000
# Iterartion 21: x= -3.00000, f(x)= 0.00000
# Iterartion 22: x= -3.00000, f(x)= 0.00000
# Iterartion 23: x= -3.00000, f(x)= 0.00000
# Iterartion 24: x= -3.00000, f(x)= 0.00000
# Iterartion 25: x= -3.00000, f(x)= 0.00000
# Iterartion 26: x= -3.00000, f(x)= 0.00000
# Iterartion 27: x= -3.00000, f(x)= 0.00000
# Iterartion 28: x= -3.00000, f(x)= 0.00000
# Iterartion 29: x= -3.00000, f(x)= 0.00000
# Iterartion 30: x= -3.00000, f(x)= 0.00000
# Iterartion 31: x= -3.00000, f(x)= 0.00000
# Iterartion 32: x= -3.00000, f(x)= 0.00000
# Iterartion 33: x= -3.00000, f(x)= 0.00000
# Iterartion 34: x= -3.00000, f(x)= 0.00000
# Iterartion 35: x= -3.00000, f(x)= 0.00000
# Iterartion 36: x= -3.00000, f(x)= 0.00000
# Iterartion 37: x= -3.00000, f(x)= 0.00000
# Iterartion 38: x= -3.00000, f(x)= 0.00000
# Iterartion 39: x= -3.00000, f(x)= 0.00000
# Iterartion 40: x= -3.00000, f(x)= 0.00000
# Iterartion 41: x= -3.00000, f(x)= 0.00000
# Iterartion 42: x= -3.00000, f(x)= 0.00000
# Iterartion 43: x= -3.00000, f(x)= 0.00000
# Iterartion 44: x= -3.00000, f(x)= 0.00000
# Iterartion 45: x= -3.00000, f(x)= 0.00000
# Iterartion 46: x= -3.00000, f(x)= 0.00000
# Iterartion 47: x= -3.00000, f(x)= 0.00000
# Iterartion 48: x= -3.00000, f(x)= 0.00000
# Iterartion 49: x= -3.00000, f(x)= 0.00000
# Iterartion 50: x= -3.00000, f(x)= 0.00000

# %%
print(f"\nlocal minima : x={x:.5f} , f(x)={func(x):.5f}")
# Out:
# local minima : x=-3.00000 , f(x)=0.00000

# %%
x_plot = [i for i in range(-10,5)]
y_plot=[func(i) for i in x_plot]

plt.figure(figsize=(8,5))
plt.plot(x_plot,y_plot, label ="y=(x+3)^2")
plt.scatter(x_vals,y_vals,color='red',label="Gradient Descent Steps")
plt.plot(x_vals,y_vals,linestyle='--',color='gray',alpha = 0.6)
plt.title("Gradient Descent to find local minima")
plt.xlabel("x")
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
